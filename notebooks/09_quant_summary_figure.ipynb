# %% [markdown]
# # Summary figure showing all N standards against reference value

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Set up to find custom python package
import os
import sys
import numpy as np
sys.path.insert(1, ".")
sys.path.insert(1, "..")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read in the summary tables for each sample

# %%
file_list = [
    "../data/processed/buddingtonite_ANU/nitrogen_summary.csv",
    "../data/processed/hyalophane_StA/N_summary.csv",
    "../data/processed/basaltic_glasses/N_summary_D2872.csv",
    "../data/processed/basaltic_glasses/N_summary_D2893.csv",
    "../data/processed/basaltic_glasses/N_summary_Edi06.csv",
    "../data/processed/basaltic_glasses/N_summary_Edi09.csv",
    "../data/processed/rhyolitic_glasses/N_summary.csv"
]

summary_dfs = []

for f in file_list:
    summary_dfs.append(
        pd.read_csv(f, header = [0, 1], index_col=0)
    )

# %%
summary_dfs[0]
# Out:
#                        1_base                           \
#               N wt% (average) N detlim N detlim (orig)
# sample
# buddingtonite         4.28091      NaN          0.0266
#
#                                                                            \
#               N stdev abs (individual spots) N stdev abs (multiple spots)
# sample
# buddingtonite                        0.82628                     0.193604
#
#                          2_bg                            \
#               N wt% (average)  N detlim N detlim (orig)
# sample
# buddingtonite         4.39946  0.037786          0.0266
#
#                                                                            \
#               N stdev abs (individual spots) N stdev abs (multiple spots)
# sample
# buddingtonite                       0.855089                     0.202435
#
#                      3_bg_apf                            \
#               N wt% (average)  N detlim N detlim (orig)
# sample
# buddingtonite        5.201822  0.044981          0.0266
#
#
#               N stdev abs (individual spots) N stdev abs (multiple spots)
# sample
# buddingtonite                       1.011043                      0.23825

# %%
sample_list = [
    "buddingtonite",
    "hyalophane",
    "D2872",
    "D2893",
    "Edi06",
    "Edi09",
    "A870",
    "A876",
    "B989"
]

# %%
combined_df_all = pd.concat(summary_dfs)
combined_df_all.to_csv("../data/processed/nitrogen_summary_all_samples.csv")
combined_df_all
# Out:
#                              1_base                           \
#                     N wt% (average) N detlim N detlim (orig)
# sample
# buddingtonite              4.280910      NaN        0.026600
# hyalophane_BNcalib         0.000000      NaN        0.023960
# hyalophane_GaNcalib        0.000000      NaN        0.019520
# D2872                      0.000000      NaN        0.019036
# D2893                      0.000000      NaN        0.017576
# Edi06                      0.000000      NaN        0.011840
# Edi09                      0.000000      NaN        0.013815
# A870                       0.555614      NaN        0.025225
# A876                       0.218989      NaN        0.025033
# B989                       0.649115      NaN        0.025200
#
#                                                     \
#                     N stdev abs (individual spots)
# sample
# buddingtonite                             0.826280
# hyalophane_BNcalib                        0.000000
# hyalophane_GaNcalib                       0.000000
# D2872                                     0.000000
# D2893                                     0.000000
# Edi06                                     0.000000
# Edi09                                     0.000000
# A870                                      0.028466
# A876                                      0.026327
# B989                                      0.029485
#
#                                                             2_bg            \
#                     N stdev abs (multiple spots) N wt% (average)  N detlim
# sample
# buddingtonite                           0.193604        4.399460  0.037786
# hyalophane_BNcalib                      0.000000        0.162832  0.018134
# hyalophane_GaNcalib                     0.000000        0.192356  0.013437
# D2872                                   0.000000        0.181807  0.020428
# D2893                                   0.000000        0.058553  0.019430
# Edi06                                   0.000000        0.010434  0.021787
# Edi09                                   0.000000        0.087706  0.025307
# A870                                    0.033874        0.948490  0.020582
# A876                                    0.107923        0.601556  0.021307
# B989                                    0.029717        1.051853  0.022645
#
#                                                                     \
#                     N detlim (orig) N stdev abs (individual spots)
# sample
# buddingtonite              0.026600                       0.855089
# hyalophane_BNcalib         0.023960                       0.013042
# hyalophane_GaNcalib        0.019520                       0.013189
# D2872                      0.019036                       0.019067
# D2893                      0.017576                       0.015285
# Edi06                      0.011840                       0.007417
# Edi09                      0.013815                       0.013802
# A870                       0.025225                       0.024366
# A876                       0.025033                       0.021540
# B989                       0.025200                       0.024874
#
#                                                         3_bg_apf            \
#                     N stdev abs (multiple spots) N wt% (average)  N detlim
# sample
# buddingtonite                           0.202435        5.201822  0.044981
# hyalophane_BNcalib                      0.015961        0.171390  0.019089
# hyalophane_GaNcalib                     0.008271        0.228927  0.015996
# D2872                                   0.025487        0.219041  0.024611
# D2893                                   0.015580        0.070546  0.023410
# Edi06                                   0.014954        0.012571  0.026247
# Edi09                                   0.017495        0.105669  0.030490
# A870                                    0.036775        1.142613  0.024798
# A876                                    0.104986        0.724705  0.025671
# B989                                    0.024232        1.267120  0.027283
#
#                                                                     \
#                     N detlim (orig) N stdev abs (individual spots)
# sample
# buddingtonite              0.026600                       1.011043
# hyalophane_BNcalib         0.023960                       0.014202
# hyalophane_GaNcalib        0.019520                       0.016622
# D2872                      0.019036                       0.024572
# D2893                      0.017576                       0.018639
# Edi06                      0.011840                       0.008957
# Edi09                      0.013815                       0.017084
# A870                       0.025225                       0.050722
# A876                       0.025033                       0.036996
# B989                       0.025200                       0.054726
#
#
#                     N stdev abs (multiple spots)
# sample
# buddingtonite                           0.238250
# hyalophane_BNcalib                      0.016799
# hyalophane_GaNcalib                     0.009840
# D2872                                   0.030707
# D2893                                   0.018771
# Edi06                                   0.018015
# Edi09                                   0.021078
# A870                                    0.044298
# A876                                    0.126471
# B989                                    0.029186

# %%
combined_df = pd.concat([df.loc[:, "3_bg_apf"] for df in summary_dfs])
combined_df.rename(index = {"hyalophane_BNcalib": "hyalophane"}, inplace=True)
combined_df = combined_df.loc[sample_list, :]
combined_df
# Out:
#                N wt% (average)  N detlim  N detlim (orig)  \
# sample
# buddingtonite         5.201822  0.044981         0.026600
# hyalophane            0.171390  0.019089         0.023960
# D2872                 0.219041  0.024611         0.019036
# D2893                 0.070546  0.023410         0.017576
# Edi06                 0.012571  0.026247         0.011840
# Edi09                 0.105669  0.030490         0.013815
# A870                  1.142613  0.024798         0.025225
# A876                  0.724705  0.025671         0.025033
# B989                  1.267120  0.027283         0.025200
#
#                N stdev abs (individual spots)  N stdev abs (multiple spots)
# sample
# buddingtonite                        1.011043                      0.238250
# hyalophane                           0.014202                      0.016799
# D2872                                0.024572                      0.030707
# D2893                                0.018639                      0.018771
# Edi06                                0.008957                      0.018015
# Edi09                                0.017084                      0.021078
# A870                                 0.050722                      0.044298
# A876                                 0.036996                      0.126471
# B989                                 0.054726                      0.029186

# %%
reference = {
    "buddingtonite": [5.44, np.NaN],
    "hyalophane":  [0.113, 0.015], # from mosenfelder
    "D2872": [0.38, 0.02],
    "D2893": [0.058, 0.011],
    "Edi06": [0, np.NaN],
    "Edi09": [0.124, 0.007],
    "A870": [1.0, 0.4],
    "A876": [0.5, 0.3],
    "B989": [0.9, 0.3]
}

# %%
combined_df[["Reference N wt%", "Reference N stdev"]] = [reference[s] for s in sample_list]

# %%
combined_df
# Out:
#                N wt% (average)  N detlim  N detlim (orig)  \
# sample
# buddingtonite         5.201822  0.044981         0.026600
# hyalophane            0.171390  0.019089         0.023960
# D2872                 0.219041  0.024611         0.019036
# D2893                 0.070546  0.023410         0.017576
# Edi06                 0.012571  0.026247         0.011840
# Edi09                 0.105669  0.030490         0.013815
# A870                  1.142613  0.024798         0.025225
# A876                  0.724705  0.025671         0.025033
# B989                  1.267120  0.027283         0.025200
#
#                N stdev abs (individual spots)  N stdev abs (multiple spots)  \
# sample
# buddingtonite                        1.011043                      0.238250
# hyalophane                           0.014202                      0.016799
# D2872                                0.024572                      0.030707
# D2893                                0.018639                      0.018771
# Edi06                                0.008957                      0.018015
# Edi09                                0.017084                      0.021078
# A870                                 0.050722                      0.044298
# A876                                 0.036996                      0.126471
# B989                                 0.054726                      0.029186
#
#                Reference N wt%  Reference N stdev
# sample
# buddingtonite            5.440                NaN
# hyalophane               0.113              0.015
# D2872                    0.380              0.020
# D2893                    0.058              0.011
# Edi06                    0.000                NaN
# Edi09                    0.124              0.007
# A870                     1.000              0.400
# A876                     0.500              0.300
# B989                     0.900              0.300

# %%
plt.rcParams["font.family"] = "arial"
plt.rcParams["font.size"] = 10

df = combined_df
fig, ax = plt.subplots(figsize=(10*0.39,8*0.39))
# fig = plt.figure(figsize=(8*0.39, 12*0.39))

plt.errorbar(
    df["Reference N wt%"], 
    df["N wt% (average)"],
    xerr=df["Reference N stdev"],
    yerr=df["N stdev abs (multiple spots)"],
    fmt = ".k",
    lw = 0.5)

plt.axline((0,0), (6,6), color="red", lw=0.5)
plt.xlabel("N wt% (reference value)")
plt.ylabel("N wt% (this study)")

ax.set_xticks(np.arange(0, 8, 2))
ax.set_yticks(np.arange(0, 8, 2))

plt.rcParams["font.size"] = 8
iax = ax.inset_axes(
    [3.7, -0.3, 5, 5],
    transform=ax.transData
)

df_subset = df.loc[df["Reference N wt%"] < 0.5]

iax.errorbar(
    df_subset["Reference N wt%"], 
    df_subset["N wt% (average)"],
    xerr=df_subset["Reference N stdev"],
    yerr=df_subset["N stdev abs (multiple spots)"],
    fmt = ".k",
    lw=0.5)

iax.axline((0,0), (0.25, 0.25), color="red", lw=0.5)

ax.set_aspect(aspect="equal")

# iax.set_xlim(-0.05, 0.5)
# iax.set_ylim(-0.05, 0.5)

iax.set_xticks(np.arange(0, 0.6, 0.1))
iax.set_yticks(np.arange(0, 0.4, 0.1))
iax.set_aspect("equal", adjustable="box")

# ax.indicate_inset_zoom(
#     iax,
#     edgecolor = "red"
#     )

patch, connector_lines = ax.indicate_inset(
    [-0.1, -0.1, 0.6, 0.45],
    inset_ax=iax,
    facecolor="grey",
    alpha=0.2,
    edgecolor="k"
)

connector_lines[0].set_visible(False)
connector_lines[1].set_visible(False)
# connector_lines[2].set_visible(True)
# connector_lines[3].set_visible(True)

iax.set_facecolor([0.95, 0.95, 0.95])

plt.tight_layout()
plt.savefig("../figures/N_quant_summary_figure.pdf")
plt.show()
