# %% [markdown]
# # Plot the result of peak position analysis
#
# For buddingtonite and D2872 glass

# %%
import sys
sys.path.insert(1, "..")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.transforms as mtransforms
from matplotlib.ticker import FormatStrFormatter
import numpy as np
import pickle
from src import correct_quant

# %% [markdown]
# Summarise results for buddingtonite

# %%
with open('../data/interim/peak_positions/buddingtonite_StA/buddingtonite.pickle', 'rb') as f:
    data = pickle.load(f)

peak_pos = []
kraw_pcnt = []
kraw_stdev_pcnt = []
raw_cps = []
raw_cps_stdev = []
comment = []
date = []

for d in data:
    peak_pos.append(d.corrected.loc[d.corrected['element'] == 'N', 'pos'].values[0])
    kraw_pcnt.append(d.montecarlo.loc[d.montecarlo['element'] == 'N', 'kraw_pcnt'].values[0])
    kraw_stdev_pcnt.append(d.montecarlo.loc[d.montecarlo['element'] == 'N', 'kraw_stdev_pcnt'].values[0])
    raw_cps.append(d.peak.loc[2, 'raw_cps'])
    raw_cps_stdev.append(d.peak.loc[2, 'stdev_raw_cps'])
    comment.append(d.info.comment)
    date.append(d.info.date)
    
df_budd = pd.DataFrame({'peak_pos': peak_pos, 
                'kraw_pcnt': kraw_pcnt, 'kraw_stdev_pcnt': kraw_stdev_pcnt, 
                'raw_cps': raw_cps, 'raw_cps_stdev': raw_cps_stdev,
                'comment': comment, 'date': date})
df_budd.sort_values('peak_pos')
# Out:
#     peak_pos  kraw_pcnt  kraw_stdev_pcnt    raw_cps  raw_cps_stdev                                 comment        date
# 0    145.800   6.175353         4.191449  36.953571       1.109858  budd_10nA_30s_03um_145.8mm_BNcalibr_01  2021-12-01
# 1    145.800   5.872971         3.450994  35.314286       1.084962  budd_10nA_30s_03um_145.8mm_BNcalibr_02  2021-12-01
# 2    145.800   5.838970         4.286849  35.139286       1.082271  budd_10nA_30s_03um_145.8mm_BNcalibr_03  2021-12-01
# 3    145.800   6.249229         3.732389  37.260714       1.114461  budd_10nA_30s_03um_145.8mm_BNcalibr_04  2021-12-01
# 8    146.400   7.315948         3.215839  41.867857       1.181353  budd_10nA_30s_03um_146.4mm_BNcalibr_05  2021-12-01
# 7    146.400   6.354198         2.964632  36.800000       1.107550  budd_10nA_30s_03um_146.4mm_BNcalibr_04  2021-12-01
# 9    146.400   7.283795         3.384252  42.367857       1.188386  budd_10nA_30s_03um_146.4mm_BNcalibr_06  2021-12-01
# 5    146.400   7.096009         3.775549  41.310714       1.173467  budd_10nA_30s_03um_146.4mm_BNcalibr_02  2021-12-01
# 4    146.400   7.425025         3.611414  43.207143       1.200099  budd_10nA_30s_03um_146.4mm_BNcalibr_01  2021-12-01
# 6    146.400   6.856860         3.645466  39.700000       1.150362  budd_10nA_30s_03um_146.4mm_BNcalibr_03  2021-12-01
# 10   146.600   7.252665         3.274868  42.082143       1.184372  budd_10nA_30s_03um_146.6mm_BNcalibr_01  2021-12-01
# 11   146.600   7.457775         3.544772  43.132143       1.199057  budd_10nA_30s_03um_146.6mm_BNcalibr_02  2021-12-01
# 12   146.600   7.518957         3.464954  43.178571       1.199702  budd_10nA_30s_03um_146.6mm_BNcalibr_03  2021-12-01
# 13   146.600   7.576706         3.419832  43.817857       1.208551  budd_10nA_30s_03um_146.6mm_BNcalibr_04  2021-12-01
# 14   146.600   7.434972         3.483550  42.814286       1.194631  budd_10nA_30s_03um_146.6mm_BNcalibr_05  2021-12-01
# 15   146.600   6.613257         3.822974  39.064286       1.141115  budd_10nA_30s_03um_146.6mm_BNcalibr_06  2021-12-01
# 30   146.800   6.783602         3.465499  39.721429       1.150673  budd_10nA_30s_03um_146.8mm_BNcalibr_02  2021-12-01
# 32   146.800   6.997068         3.161359  40.682143       1.164505  budd_10nA_30s_03um_146.8mm_BNcalibr_04  2021-12-01
# 31   146.800   7.026478         3.227090  40.653571       1.164096  budd_10nA_30s_03um_146.8mm_BNcalibr_03  2021-12-01
# 29   146.800   6.688535         3.571996  38.528571       1.133263  budd_10nA_30s_03um_146.8mm_BNcalibr_01  2021-12-01
# 34   146.800   7.140491         3.423177  41.271429       1.172908  budd_10nA_30s_03um_146.8mm_BNcalibr_06  2021-12-01
# 33   146.800   6.647541         3.598983  38.485714       1.132633  budd_10nA_30s_03um_146.8mm_BNcalibr_05  2021-12-01
# 21   146.996   6.597993         3.639022  37.978571       1.125145  budd_10nA_30s_03um_146.7mm_BNcalibr_05  2021-12-01
# 22   146.996   6.496738         3.392281  37.403571       1.116596  budd_10nA_30s_03um_146.7mm_BNcalibr_07  2021-12-01
# 23   146.996   6.240843         5.015254  36.439286       1.908908  budd_10nA_10s_03um_146.7mm_BNcalibr_01  2021-12-01
# 24   146.996   7.037089         6.034511  40.521429       2.012994  budd_10nA_10s_03um_146.7mm_BNcalibr_02  2021-12-01
# 25   146.996   7.012049         5.507036  40.685714       2.017070  budd_10nA_10s_05um_146.7mm_BNcalibr_03  2021-12-01
# 26   146.996   7.365611         5.439348  42.828571       2.069506  budd_10nA_10s_05um_146.7mm_BNcalibr_04  2021-12-01
# 27   146.996   8.116762         5.267110  45.932143       2.143179  budd_10nA_10s_05um_146.7mm_BNcalibr_05  2021-12-01
# 28   146.996   6.938097         6.039388  40.542857       2.013526  budd_10nA_10s_03um_146.7mm_BNcalibr_06  2021-12-01
# 20   146.996   7.196080         3.305862  41.296429       1.173264  budd_10nA_30s_05um_146.7mm_BNcalibr_04  2021-12-01
# 19   147.600   6.485313         3.693125  37.839286       1.123080  budd_10nA_30s_03um_147.6mm_BNcalibr_04  2021-12-01
# 18   147.600   6.113276         3.460377  35.689286       1.090708  budd_10nA_30s_03um_147.6mm_BNcalibr_03  2021-12-01
# 16   147.600   5.967963         3.463087  35.557143       1.088686  budd_10nA_30s_03um_147.6mm_BNcalibr_01  2021-12-01
# 17   147.600   6.079533         3.386005  36.017857       1.095717  budd_10nA_30s_03um_147.6mm_BNcalibr_02  2021-12-01

# %%
data[0].corrected
# Out:
#   element      pos      net_cps  stdev_net_cps  dl_ppm   kraw_pcnt  time      raw_cps  kraw_stdev_pcnt  stdev_raw_cps  kraw_apf_pcnt  kraw_stdev_apf_pcnt
# 0      Al   90.644  1241.300000           0.64   203.0  105.504000  20.0  1257.850000         0.771038       7.930479     105.414342             0.771038
# 1      Si  228.028   729.300000           0.83   205.0   98.973000  20.0   729.850000         0.984784       6.040902      99.049913             0.984784
# 2       N  145.800    30.361876           4.52  1081.0    6.189158  30.0    36.953571         4.536794       1.109858       6.175353             4.536794

# %%
with open('../data/interim/peak_positions/D2872_StA/D2872.pickle', 'rb') as f:
    data = pickle.load(f)

peak_pos = []
kraw_pcnt = []
kraw_stdev_pcnt = []
raw_cps = []
raw_cps_stdev = []
comment = []
date = []

for d in data:
    peak_pos.append(d.corrected.loc[d.corrected['element'] == 'N', 'pos'].values[0])
    kraw_pcnt.append(d.montecarlo.loc[d.montecarlo['element'] == 'N', 'kraw_pcnt'].values[0])
    kraw_stdev_pcnt.append(d.montecarlo.loc[d.montecarlo['element'] == 'N', 'kraw_stdev_pcnt'].values[0])
    raw_cps.append(d.peak.loc[0, 'raw_cps'])
    raw_cps_stdev.append(d.peak.loc[0, 'stdev_raw_cps'])
    comment.append(d.info.comment)
    date.append(d.info.date)
    
df_glass = pd.DataFrame({'peak_pos': peak_pos, 
                'kraw_pcnt': kraw_pcnt, 'kraw_stdev_pcnt': kraw_stdev_pcnt, 
                'raw_cps': raw_cps, 'raw_cps_stdev': raw_cps_stdev,
                'comment': comment, 'date': date})
df_glass.sort_values('peak_pos')
# Out:
#     peak_pos  kraw_pcnt  kraw_stdev_pcnt    raw_cps  raw_cps_stdev                  comment        date
# 0    145.000   0.712051        15.900679  33.577273       0.610803  D2872_50nA_20um_145.0_1  2021-11-18
# 1    145.000   0.575528        19.642099  32.290909       0.598989  D2872_50nA_20um_145.0_2  2021-11-18
# 2    145.000   0.466882        22.779651  31.818182       0.594588  D2872_50nA_20um_145.0_3  2021-11-18
# 3    145.000   0.519684        20.095570  32.590909       0.601765  D2872_50nA_20um_145.0_4  2021-11-18
# 4    145.000   0.719120        14.188037  32.840909       0.604069  D2872_50nA_20um_145.0_5  2021-11-18
# 5    145.200   0.691312        15.817078  35.459091       0.627686  D2872_50nA_20um_145.2_1  2021-11-18
# 6    145.200   0.703490        17.130770  34.054545       0.615129  D2872_50nA_20um_145.2_2  2021-11-18
# 7    145.200   0.806175        13.537378  34.827273       0.622069  D2872_50nA_20um_145.2_3  2021-11-18
# 8    145.200   0.585800        19.096402  33.731818       0.612207  D2872_50nA_20um_145.2_4  2021-11-18
# 9    145.200   0.573999        19.076797  33.322727       0.608484  D2872_50nA_20um_145.2_5  2021-11-18
# 14   145.400   0.942207        11.136520  34.672727       0.620687  D2872_50nA_20um_145.4_5  2021-11-18
# 13   145.400   0.636413        16.230047  33.340909       0.608650  D2872_50nA_20um_145.4_4  2021-11-18
# 10   145.400   0.837921        10.525967  33.900000       0.613732  D2872_50nA_20um_145.4_1  2021-11-18
# 11   145.400   0.802079        14.036390  33.981818       0.614472  D2872_50nA_20um_145.4_2  2021-11-18
# 12   145.400   0.850488        13.533603  34.390909       0.618160  D2872_50nA_20um_145.4_3  2021-11-18
# 15   145.600   0.792894        13.165672  33.895455       0.613691  D2872_50nA_20um_145.6_1  2021-11-18
# 16   145.600   0.727681        16.684425  33.581818       0.610845  D2872_50nA_20um_145.6_2  2021-11-18
# 17   145.600   0.581444        17.623519  33.195455       0.607321  D2872_50nA_20um_145.6_3  2021-11-18
# 18   145.600   0.697025        14.491274  33.640909       0.611382  D2872_50nA_20um_145.6_4  2021-11-18
# 19   145.600   0.557951        19.664978  32.377273       0.599790  D2872_50nA_20um_145.6_5  2021-11-18
# 23   145.800   0.614082        16.422011  32.645455       0.602268  D2872_50nA_20um_145.8_4  2021-11-18
# 22   145.800   0.782125        13.059609  34.440909       0.618609  D2872_50nA_20um_145.8_3  2021-11-18
# 24   145.800   0.944045        11.520282  35.486364       0.627927  D2872_50nA_20um_145.8_5  2021-11-18
# 20   145.800   0.737648        13.206334  33.831818       0.613114  D2872_50nA_20um_145.8_1  2021-11-18
# 21   145.800   0.724503        16.201065  34.050000       0.615088  D2872_50nA_20um_145.8_2  2021-11-18
# 25   146.000   0.796007        13.721533  33.790909       0.612743  D2872_50nA_20um_146.0_1  2021-11-18
# 26   146.000   0.849079        12.269422  34.422727       0.618445  D2872_50nA_20um_146.0_2  2021-11-18
# 27   146.000   0.835602        13.213234  34.304545       0.617383  D2872_50nA_20um_146.0_3  2021-11-18
# 28   146.000   0.825751        13.834730  34.218182       0.616605  D2872_50nA_20um_146.0_4  2021-11-18
# 29   146.000   0.872802        11.790163  34.604545       0.620077  D2872_50nA_20um_146.0_5  2021-11-18
# 30   146.200   0.872841        12.320648  34.545455       0.619547  D2872_50nA_20um_146.2_1  2021-11-18
# 31   146.200   0.866183        12.269822  34.022727       0.614842  D2872_50nA_20um_146.2_2  2021-11-18
# 32   146.200   1.001923        11.922207  35.145455       0.624904  D2872_50nA_20um_146.2_3  2021-11-18
# 33   146.200   0.957551         9.639502  33.818182       0.612991  D2872_50nA_20um_146.2_4  2021-11-18
# 34   146.200   0.850184        12.375321  34.295455       0.617301  D2872_50nA_20um_146.2_5  2021-11-18
# 39   146.400   0.677238        16.221709  32.454545       0.600505  D2872_50nA_20um_146.4_5  2021-11-18
# 38   146.400   1.020812         7.662435  33.750000       0.612372  D2872_50nA_20um_146.4_4  2021-11-18
# 36   146.400   0.846974        12.639912  33.850000       0.613279  D2872_50nA_20um_146.4_2  2021-11-18
# 35   146.400   0.969547        10.691217  33.850000       0.613279  D2872_50nA_20um_146.4_1  2021-11-18
# 37   146.400   1.126916         9.241099  35.727273       0.630055  D2872_50nA_20um_146.4_3  2021-11-18
# 40   146.606   1.044975        10.648795  33.913636       0.613855  D2872_50nA_20um_146.6_1  2021-11-18
# 41   146.606   0.955445        10.485015  33.231818       0.607653  D2872_50nA_20um_146.6_2  2021-11-18
# 42   146.606   1.021987         8.873883  34.136364       0.615868  D2872_50nA_20um_146.6_3  2021-11-18
# 43   146.606   0.963217        10.837805  34.172727       0.616196  D2872_50nA_20um_146.6_4  2021-11-18
# 44   146.606   1.052963        11.363120  35.181818       0.625227  D2872_50nA_20um_146.6_5  2021-11-18
# 48   147.000   0.813574        14.101049  32.695455       0.602729  D2872_50nA_20um_147.0_4  2021-11-18
# 45   147.000   0.946339        10.755968  33.022727       0.605739  D2872_50nA_20um_147.0_1  2021-11-18
# 46   147.000   0.950733        10.107848  33.277273       0.608069  D2872_50nA_20um_147.0_2  2021-11-18
# 47   147.000   1.044823         9.924358  33.618182       0.611175  D2872_50nA_20um_147.0_3  2021-11-18
# 49   147.000   0.920871         9.329489  32.145455       0.597638  D2872_50nA_20um_147.0_5  2021-11-18

# %%
def calc_means(df):
    df_means = df.groupby('peak_pos').mean()[['kraw_pcnt', 'raw_cps']]
    df_means = df_means.rename(columns={nm: nm + '_mean' for nm in df_means.columns})
    df_stdev = df.groupby('peak_pos').std()[['kraw_pcnt', 'raw_cps']]
    df_stdev = df_stdev.rename(columns={nm: nm + '_stdev' for nm in df_stdev.columns})
    df_means = pd.concat([df_means, df_stdev], axis=1)
    return df_means

# %%
df_budd_means = calc_means(df_budd)
df_glass_means = calc_means(df_glass)

# %%
df_glass_means.head()
# Out:
#           kraw_pcnt_mean  raw_cps_mean  kraw_pcnt_stdev  raw_cps_stdev
# peak_pos
# 145.0           0.598653     32.623636         0.113474       0.655203
# 145.2           0.672155     34.279091         0.095397       0.859864
# 145.4           0.813822     34.057273         0.111825       0.508356
# 145.6           0.671399     33.338182         0.099433       0.592721
# 145.8           0.760481     34.090909         0.119804       1.028097

# %%
fig, axs = plt.subplots(ncols=1, nrows=3, figsize = (8*0.39, 18*0.39), sharex=True)
titlefontsize = 10
# Panel A: raw cps for glass
ax = axs[0]
ax.set_ylabel("raw cps")
ax.set_title("Glass D2872", fontsize=titlefontsize, loc="left")
ax.errorbar(x=df_glass['peak_pos'],
             y=df_glass['raw_cps'],
             yerr=df_glass['raw_cps_stdev'],
             fmt='x', color=[0.3]*3,
             lw=1)

ax.errorbar(x=df_glass_means.index,
            y=df_glass_means['raw_cps_mean'],
            # yerr=df_means['kraw_pcnt_stdev'],
            fmt='ok',
            markersize=8)

# Panel B: kraw for glass
ax = axs[1]
ax.set_ylabel("k-ratio %")
ax.set_title("Glass D2872 - background-corrected", fontsize=titlefontsize, loc="left")
ax.errorbar(x=df_glass['peak_pos'],
             y=df_glass['kraw_pcnt'],
             yerr=df_glass['kraw_pcnt'] * (df_glass['kraw_stdev_pcnt']/100),
             fmt='x', color=[0.3]*3,
             lw=1)

ax.errorbar(x=df_glass_means.index,
            y=df_glass_means['kraw_pcnt_mean'],
            # yerr=df_means['kraw_pcnt_stdev'],
            fmt='ok',
            markersize=8)

# Panel C: kraw for glass
ax = axs[2]
ax.set_ylabel("k-ratio %")
ax.set_title("Buddingtonite - background-corrected", fontsize=titlefontsize, loc="left")
ax.errorbar(x=df_budd['peak_pos'],
             y=df_budd['kraw_pcnt'],
             yerr=df_budd['kraw_pcnt'] * (df_budd['kraw_stdev_pcnt']/100),
             fmt='x', color=[0.3]*3,
             lw=1, label="Spot analysis")

ax.errorbar(x=df_budd_means.index,
            y=df_budd_means['kraw_pcnt_mean'],
            # yerr=df_means['kraw_pcnt_stdev'],
            fmt='ok',
            markersize=8, label="Mean")

ax.legend(fontsize=8, frameon=False, borderpad=0.2, edgecolor="w", handletextpad=0.2, markerscale=0.8)

# Annotations

plt.xlabel('Spectrometer position, L (mm)')
axs[2].set_xticks(np.arange(145, 149, 1))
# set minor ticks
axs[2].set_xticks(np.arange(145, 149, 0.2), minor=True)
axs[2].set_xlim(144.8, 148.2)

for ax in axs:
    ax.axvline(146.6, linestyle='--', zorder=0, lw=3, color='tab:blue', alpha=0.2)
    ax.axvline(147.0, linestyle='--', zorder=0, lw=3, color='tab:orange', alpha=0.2)

plt.sca(axs[0])
plt.annotate('GaN', 
             xy=(146.6, 36.7), xycoords='data', 
             xytext=(146.6, 37.3), textcoords='data', fontsize=10, color="tab:blue",
             arrowprops=dict(width=1, headwidth=7, headlength=5, facecolor='tab:blue', lw=1, alpha=0.5), 
             annotation_clip=False,
             ha='center')

plt.annotate('BN', 
             xy=(147.0, 36.7), xycoords='data', 
             xytext=(147.0, 37.3), textcoords='data', fontsize=10, color="tab:orange",
             arrowprops=dict(width=1, headwidth=7, headlength=5, facecolor='tab:orange', lw=1, alpha=0.5),  
             annotation_clip=False,
             ha='center')

letterlabel = "ABC"
trans = mtransforms.ScaledTranslation(-5/72, -5/72, fig.dpi_scale_trans)

for i, letter in enumerate(letterlabel):
    axs[i].text(1.0, 1.0, letter, transform=axs[i].transAxes + trans,
            fontsize=12, ha='right', va='top', fontfamily='Arial',
            # bbox=dict(facecolor='w', edgecolor='grey', pad=3.0)
            )

plt.tight_layout()
plt.savefig("../figures/peak_positions.png")
plt.savefig("../figures/for_submission/Figure_9.pdf", dpi=600)

plt.show()
